# %%
from app.data_analysis.data_analysis import technologies_analysis
from app.config import to_find


if __name__ == '__main__':
    technologies_analysis()

    # Reset all values in the dictionary
    to_find = to_find.fromkeys(to_find, 0)
